# %%
import pandas as pd

# %%
df = pd.read_csv("ObesityLevelsFinal.csv", index_col=0)

# %%
df.head()
# Out:
#          Age  Gender    Height    Weight      CALC      FAVC      FCVC  \
# ID
# 1   0.347845     1.0 -0.345456  2.457898 -1.365458 -2.895565 -0.326598
# 2   0.347845     1.0 -0.345456  2.457898  1.565896  2.321254 -0.326598
# 3   1.124578     1.0 -0.345456  2.457898 -1.365458 -2.895565 -0.326598
# 4   1.124578    -1.0  0.123212  2.457898 -1.365458 -2.895565 -0.326598
# 5   0.347845     1.0  0.123212  2.457898 -1.365458 -2.895565 -0.326598
#
#          NCP       SCC     SMOKE      CH2O  family_history_with_overweight  \
# ID
# 1  -0.212545 -0.235655  2.632366  0.658965                             1.0
# 2  -0.875454 -0.235655  2.632366  0.658965                            -1.0
# 3   0.654587 -0.235655  2.632366  0.658965                             1.0
# 4  -0.212545 -0.235655  2.632366 -1.254654                             1.0
# 5   0.654587 -0.235655  2.632366 -1.254654                             1.0
#
#          FAF       TUE      CAEC    MTRANS
# ID
# ...

# %%
print(df.columns)
# Out:
# Index(['Age', 'Gender', 'Height', 'Weight', 'CALC', 'FAVC', 'FCVC', 'NCP',
#        'SCC', 'SMOKE', 'CH2O', 'family_history_with_overweight', 'FAF', 'TUE',
#        'CAEC', 'MTRANS'],
#       dtype='object')

# %%
age_rep = {
     1.878454: 0,  # 14 - 16
     1.124578: 1,  # 17 - 18
     0.347845: 2,  # 19 - 21
    -0.578746: 3,  # 22 - 25
    -1.254587: 4,  # 26 - 35
    -2.312121: 5,  # 35 - 50
    -1.432312: 6   # 50+
}   
gen_rep = {
     1.000000: 0,  # Mujer
    -1.000000: 1   # Hombre
}
height_rep = {
    -0.345456: 0,  # 1.45 - 1.60
     0.123212: 1,  # 1.60 - 1.70
     0.354569: 2,  # 1.70 - 1.80
     0.452221: 3,  # 1.80 - 2
}
weight_rep = {
     2.457898: 0,  # 39 - 50
     1.872354: 1,  # 50 - 60
     1.236546: 2,  # 60 - 70
     0.232365: 3,  # 70 - 80
    -0.682124: 4,  # 80 - 90
    -1.545458: 5,  # 90 - 110
    -2.548785: 6,  # 110 - 130
    -3.565458: 7   # 130+
}
calc_rep = {
    -1.365458: 0,  # Sometimes
     1.565896: 1,  # No
    -2.236544: 2,  # Frequently
    -3.587458: 3   # Always
}
favc_rep = {
    -2.895565: 0,  # Yes
     2.321254: 1   # No
}
fcvc_rep = {
    -0.326598: 0,  # 1 - 1,7
     1.365698: 1,  # 1,7 - 2,3
     3.124578: 2   # 2,3 - 3
}
ncp_rep = {
    -0.875454: 0,  # 1 - 2
    -0.212545: 1,  # 2 - 3
     0.654587: 2   # 3 - 4
}
scc_rep = {
     3.365698: 0,  # Yes
    -0.235655: 1   # No
}
smoke_rep = {
    -2.455656: 0,  # Yes
    2.6323665: 1   # No
}
ch2o_rep = {
    -1.254654: 0,  # 1 - 1,7
     0.658965: 1,  # 1,7 - 2,3
     1.451254: 2   # 2,3 - 3
}
family_history_with_overweight_rep = {
    -1.000000: 0,  # Yes
     1.000000: 1   # No
}
faf_rep = {
    -0.351254: 0,  # 0 - 1
     1.124578: 1,  # 1 - 2
     3.254587: 2   # 2 - 3
}
tue_rep = {
     1.345879: 0,  # 0 - 0,7
     0.178989: 1,  # 0,7 - 1,3
    -1.987458: 2   # 1,3 - 2
}
caec_rep = {
    -2.458789: 0,  # Always
    -1.326598: 1,  # Frequently
    -0.365878: 2,  # Sometimes
     1.212125: 3   # No
}
mtrans_rep = {
    -1.542123: 0,  # Public_Transportation
    -2.124566: 1,  # Automobile
     3.845785: 2,  # Walking
     3.215564: 3,  # Bike
    -1.875456: 4   # Motorbike
}

# %%
rep_d = {
    "Age":    age_rep,
    "Gender": gen_rep,
    "Height": height_rep,
    "Weight": weight_rep,
    "CALC":   calc_rep,
    "FAVC":   favc_rep,
    "FCVC":   fcvc_rep,
    "NCP":    ncp_rep,
    "SCC":    scc_rep,
    "SMOKE":  smoke_rep,
    "CH2O":   ch2o_rep,
    "family_history_with_overweight":  family_history_with_overweight_rep,
    "FAF":    faf_rep,
    "TUE":    tue_rep,
    "CAEC":   caec_rep,
    "MTRANS": mtrans_rep
}

# %%
df_stats = df.describe().T
df_n = (df - df_stats['mean']) / df_stats['std']  # Para normalizar: (valor - promedio) / desv_estandar
df_n.describe()
# Out:
#                 Age       Gender        Height        Weight          CALC  \
# count  2.111000e+03  2111.000000  2.111000e+03  2.111000e+03  2.111000e+03
# mean   2.356134e-17     0.000000 -8.751355e-17  4.039087e-17  4.712268e-17
# std    1.000000e+00     1.000000  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.961450e+00    -0.987992 -2.088240e+00 -1.751692e+00 -2.237353e+00
# 25%   -8.871468e-01    -0.987992 -2.394968e-01 -6.286402e-01 -6.229396e-01
# 50%   -2.005890e-01    -0.987992  6.731315e-01 -1.486557e-01 -6.229396e-01
# 75%    7.406950e-01     1.011674  6.731315e-01  9.180598e-01  1.506861e+00
# max    2.295575e+00     1.011674  1.058337e+00  1.597090e+00  1.506861e+00
#
#                FAVC         FCVC           NCP           SCC         SMOKE  \
# count  2.111000e+03  2111.000000  2.111000e+03  2.111000e+03  2.111000e+03
# mean  -1.279044e-16     0.000000  1.009772e-16 -2.019544e-17 -9.310937e-16
# ...

# %%
df_n.corr()
# Out:
#                                      Age    Gender    Height    Weight  \
# Age                             1.000000  0.020271  0.046914  0.335758
# Gender                          0.020271  1.000000 -0.563127  0.176982
# Height                          0.046914 -0.563127  1.000000 -0.474083
# Weight                          0.335758  0.176982 -0.474083  1.000000
# CALC                            0.102925 -0.018943 -0.090939  0.220720
# FAVC                            0.082174  0.064934 -0.223104  0.283227
# FCVC                           -0.076566  0.229027 -0.001136 -0.152231
# NCP                             0.099342 -0.072271  0.207879  0.077179
# SCC                             0.156789  0.102633 -0.143875  0.209084
# SMOKE                           0.055043  0.044698 -0.013388  0.007425
# CH2O                            0.000437 -0.125991  0.215718 -0.174634
# family_history_with_overweight  0.259885  0.103649 -0.307699  0.520520
# ...

# %%
import matplotlib.pyplot as plt
labels = df_n.columns.to_list()
fig, ax = plt.subplots(figsize=(10, 10))
ax.imshow((df_n.corr().to_numpy()))
ax.set_xticks(np.arange(0, len(labels)))
ax.set_xticklabels(df_n.columns.to_list(), rotation=45, ha='right')
ax.set_yticks(np.arange(0, len(labels)))
ax.set_yticklabels(df_n.columns.to_list(), ha='right');

# %%
# Definir características y etiquetas que me interesan
features = ["Age","Gender","Height",
            "Weight","CALC","FAVC","FCVC",
            "NCP","SCC","CH2O","FAF","TUE","CAEC","MTRANS"]  # Seleccionar las características relevantes

#Estandarizo las etiquetas dividiendo cada columna de estas por el maximo de esa columna para que sean datos entre 0 y 1
df[features] = df[features] / df[features].max()

# %%
df.head(8)
# Out:
#          Age  Gender   Height   Weight      CALC      FAVC      FCVC  \
# ID
# 1   0.185176     1.0 -0.76391  1.00000 -0.871998 -1.247414 -0.104525
# 2   0.185176     1.0 -0.76391  1.00000  1.000000  1.000000 -0.104525
# 3   0.598672     1.0 -0.76391  1.00000 -0.871998 -1.247414 -0.104525
# 4   0.598672    -1.0  0.27246  1.00000 -0.871998 -1.247414 -0.104525
# 5   0.185176     1.0  0.27246  1.00000 -0.871998 -1.247414 -0.104525
# 6   0.185176    -1.0  0.27246  1.00000 -0.871998 -1.247414 -0.104525
# 7  -0.308097     1.0 -0.76391  0.76177 -0.871998 -1.247414 -0.104525
# 8   0.598672     1.0  0.27246  0.76177 -0.871998 -1.247414 -0.104525
#
#          NCP       SCC     SMOKE      CH2O  family_history_with_overweight  \
# ID
# 1  -0.324701 -0.070017  2.632366  0.454066                             1.0
# 2  -1.337414 -0.070017  2.632366  0.454066                            -1.0
# 3   1.000000 -0.070017  2.632366  0.454066                             1.0
# ...

# %%
labels = data.loc[:, ["type"] + features].columns.to_list()
fig, ax = plt.subplots(figsize=(10, 10))
ax.imshow((data.loc[:, ["type"] + features].corr().to_numpy()))
ax.set_xticks(np.arange(0, len(labels)))
ax.set_xticklabels(data.loc[:, ["type"] + features].columns.to_list(), rotation=45, ha='right')
ax.set_yticks(np.arange(0, len(labels)))
ax.set_yticklabels(data.loc[:, ["type"] + features].columns.to_list(), ha='right');
